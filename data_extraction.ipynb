# %% [markdown]
# Quick script extracting SC papers.

# %%
import dimcli
import pandas as pd
import time
from tqdm import tqdm
from API_keys.DIMCLI_APIKEY import API_KEY

# login
dimcli.login(key=API_KEY)
dsl = dimcli.Dsl()

all_results = []
'''
for year in tqdm(range(1950, 2025)):
    print(f"Fetching year: {year}")
    q = f"""
    search publications for "superconduct*"
    where year = {year}
    return publications[
        id + doi + title + abstract + year + journal + times_cited + concepts_scores
    ]
    """
    results = dsl.query_iterative(q, limit=1000, pause=1.0)
    all_results.extend(results.data.get("publications", []))

# save to CSV
df = pd.DataFrame(all_results)
df.to_csv("data/SC_fulldata.csv", index=False)
print(f"Saved {len(df)} records to SC_fulldata.csv")'''
print(f"Already saved records to SC_fulldata.csv, skipping...")
# Out:
# Using default endpoint: 'https://app.dimensions.ai'
# Dimcli - Dimensions API Client (v1.4)
# Connected to: <https://app.dimensions.ai/api/dsl> - DSL v2.11
# Method: manual login
# Already saved records to SC_fulldata.csv, skipping...

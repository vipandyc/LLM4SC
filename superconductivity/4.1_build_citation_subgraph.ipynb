# %% [markdown]
# Then we build citation graph (i.e. connection relation) between the ~17,500 related papers.

# %%
import dimcli
import pandas as pd
import time
from tqdm import tqdm
import math
from utils.DIMCLI_APIKEY import API_KEY

# --- load the 120k paper IDs ---
df = pd.read_csv("../data/SC_related_cites_010.csv")
df = df.dropna()
paper_ids = df["id"].dropna().unique().tolist()
print(f"{len(paper_ids)} ids loaded")

dimcli.login(key=API_KEY)
dsl = dimcli.Dsl()

# --- fetch references for a batch of up to 400 papers ---
def fetch_refs(batch):
    id_list = ", ".join(f'"{pid}"' for pid in batch)
    q = f"""
    search publications
    where id in [{id_list}]
    return publications[id + reference_ids]
    """
    return dsl.query_iterative(q, limit=400, pause=0.5).as_dataframe()


# --- loop over all paper IDs in batches ---
edges = []
batch_size = 400
total_batches = math.ceil(len(paper_ids) / batch_size)

for i in range(total_batches):
    chunk = paper_ids[i * batch_size : (i + 1) * batch_size]
    print(f"batch {i+1}/{total_batches} …")
    df_chunk = fetch_refs(chunk)

    if not df_chunk.empty:
        df_chunk = df_chunk.explode("reference_ids").dropna()
        edges.extend(zip(df_chunk["id"], df_chunk["reference_ids"]))

    time.sleep(1.0)  # be kind to the API

# --- save the citation edge list ---
edges_df = pd.DataFrame(edges, columns=["source", "target"])
edges_df.to_csv("citation_edges_outgoing.csv", index=False)
print(f"saved {len(edges_df)} edges to citation_edges_outgoing.csv")
# Out:
# Using default endpoint: 'https://app.dimensions.ai'
# 17503 ids loaded
# Dimcli - Dimensions API Client (v1.4)
# Connected to: <https://app.dimensions.ai/api/dsl> - DSL v2.11
# Method: manual login
# Starting iteration with limit=400 skip=0 ...
# batch 1/44 …
# 0-400 / 400 (6.29s)
# 400-400 / 400 (5.93s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 2/44 …
# 0-400 / 400 (0.71s)
# 400-400 / 400 (3.76s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 3/44 …
# 0-400 / 400 (0.65s)
# 400-400 / 400 (3.79s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 4/44 …
# 0-400 / 400 (0.73s)
# 400-400 / 400 (0.47s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 5/44 …
# 0-400 / 400 (3.45s)
# 400-400 / 400 (0.57s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 6/44 …
# 0-400 / 400 (4.65s)
# 400-400 / 400 (0.44s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 7/44 …
# 0-400 / 400 (4.86s)
# 400-400 / 400 (0.59s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 8/44 …
# 0-400 / 400 (4.65s)
# 400-400 / 400 (0.49s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 9/44 …
# 0-400 / 400 (3.96s)
# 400-400 / 400 (0.44s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 10/44 …
# 0-400 / 400 (4.10s)
# 400-400 / 400 (0.63s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 11/44 …
# 0-400 / 400 (4.54s)
# 400-400 / 400 (0.44s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 12/44 …
# 0-400 / 400 (4.16s)
# 400-400 / 400 (0.54s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 13/44 …
# 0-400 / 400 (3.89s)
# 400-400 / 400 (5.93s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 14/44 …
# 0-400 / 400 (5.09s)
# 400-400 / 400 (5.85s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 15/44 …
# 0-400 / 400 (0.87s)
# 400-400 / 400 (0.44s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 16/44 …
# 0-400 / 400 (4.79s)
# 400-400 / 400 (5.73s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 17/44 …
# 0-400 / 400 (0.70s)
# 400-400 / 400 (5.43s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 18/44 …
# 0-400 / 400 (1.02s)
# 400-400 / 400 (3.32s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 19/44 …
# 0-400 / 400 (0.74s)
# 400-400 / 400 (5.23s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 20/44 …
# 0-400 / 400 (0.72s)
# 400-400 / 400 (3.78s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 21/44 …
# 0-400 / 400 (0.73s)
# 400-400 / 400 (0.56s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 22/44 …
# 0-400 / 400 (4.76s)
# 400-400 / 400 (0.67s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 23/44 …
# 0-400 / 400 (4.54s)
# 400-400 / 400 (0.54s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 24/44 …
# 0-400 / 400 (4.03s)
# 400-400 / 400 (0.57s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 25/44 …
# 0-400 / 400 (4.86s)
# 400-400 / 400 (5.52s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 26/44 …
# 0-400 / 400 (5.35s)
# 400-400 / 400 (0.56s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 27/44 …
# 0-400 / 400 (4.78s)
# 400-400 / 400 (0.40s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 28/44 …
# 0-400 / 400 (4.11s)
# 400-400 / 400 (0.55s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 29/44 …
# 0-400 / 400 (0.78s)
# 400-400 / 400 (3.16s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 30/44 …
# 0-400 / 400 (0.81s)
# 400-400 / 400 (5.27s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 31/44 …
# 0-400 / 400 (5.45s)
# 400-400 / 400 (0.59s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 32/44 …
# 0-400 / 400 (0.90s)
# 400-400 / 400 (2.60s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 33/44 …
# 0-400 / 400 (0.89s)
# 400-400 / 400 (0.72s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 34/44 …
# 0-400 / 400 (3.22s)
# 400-400 / 400 (0.55s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 35/44 …
# 0-400 / 400 (0.77s)
# 400-400 / 400 (5.18s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 36/44 …
# 0-400 / 400 (0.81s)
# 400-400 / 400 (3.69s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 37/44 …
# 0-400 / 400 (0.89s)
# 400-400 / 400 (3.73s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 38/44 …
# 0-400 / 400 (0.85s)
# 400-400 / 400 (3.54s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 39/44 …
# 0-400 / 400 (5.40s)
# 400-400 / 400 (0.44s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 40/44 …
# 0-400 / 400 (0.86s)
# 400-400 / 400 (5.14s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 41/44 …
# 0-400 / 400 (5.33s)
# 400-400 / 400 (5.82s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 42/44 …
# 0-400 / 400 (0.87s)
# 400-400 / 400 (0.45s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 43/44 …
# 0-400 / 400 (3.56s)
# 400-400 / 400 (0.55s)
# ===
# Records extracted: 400
# Starting iteration with limit=400 skip=0 ...
# batch 44/44 …
# 0-303 / 303 (4.72s)
# ===
# Records extracted: 303
# saved 746495 edges to citation_edges_outgoing.csv

# %%
edges_df.head(), len(edges_df)
# Out:
# (           source          target
#  0  pub.1063133963  pub.1063094590
#  1  pub.1063133963  pub.1063133339
#  2  pub.1063133963  pub.1039490586
#  3  pub.1063133963  pub.1063132875
#  4  pub.1063133963  pub.1063091773,
#  746495)
